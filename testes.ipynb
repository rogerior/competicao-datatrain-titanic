# %% [markdown]
# ### 1. Teste e avaliação de modelos específicos
# #### 2. GridSearch na melhor técnica de classificação

# %%
# %cd drive/My Drive/Estudos/titanic-train
# Out:
# /content/drive/My Drive/Estudos/titanic-train

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
dados_train = pd.read_csv('dados/train_tratado-3_3.csv', sep=';')
dados_train.head()
# Out:
#    PassengerId  Survived  Age  SibSp  ...  Cabin_F  Cabin_G  Cabin_N  Cabin_T
# 0          476       0.0   29      0  ...        0        0        0        0
# 1           57       1.0   21      0  ...        0        0        1        0
# 2          259       1.0   35      0  ...        0        0        1        0
# 3          741       1.0   29      0  ...        0        0        0        0
# 4          699       0.0   49      1  ...        0        0        0        0
#
# [5 rows x 42 columns]

# %%
X_train_tratado = dados_train.drop(columns=['PassengerId', 'Survived'])
y_train_tratado = dados_train['Survived']
X_train_tratado.head()
# Out:
#    Age  SibSp  Parch      Fare  ...  Cabin_F  Cabin_G  Cabin_N  Cabin_T
# 0   29      0      0   52.0000  ...        0        0        0        0
# 1   21      0      0   10.5000  ...        0        0        1        0
# 2   35      0      0  512.3292  ...        0        0        1        0
# 3   29      0      0   30.0000  ...        0        0        0        0
# 4   49      1      1  110.8833  ...        0        0        0        0
#
# [5 rows x 40 columns]

# %%
dados_test = pd.read_csv('dados/test_tratado-3_3.csv', sep=';')
dados_test.head()
# Out:
#    PassengerId  Survived  Age  SibSp  ...  Cabin_F  Cabin_G  Cabin_N  Cabin_T
# 0          132       NaN   20      0  ...        0        0        1        0
# 1           39       NaN   18      1  ...        0        0        1        0
# 2          756       NaN    0      1  ...        0        0        1        0
# 3          660       NaN   58      0  ...        0        0        0        0
# 4          799       NaN   30      0  ...        0        0        1        0
#
# [5 rows x 42 columns]

# %%
X_test_tratado = dados_test.drop(columns=['PassengerId', 'Survived'])
X_test_tratado.head()
# Out:
#    Age  SibSp  Parch      Fare  ...  Cabin_F  Cabin_G  Cabin_N  Cabin_T
# 0   20      0      0    7.0500  ...        0        0        1        0
# 1   18      1      0   18.0000  ...        0        0        1        0
# 2    0      1      1   14.5000  ...        0        0        1        0
# 3   58      0      1  113.2750  ...        0        0        0        0
# 4   30      0      0    7.2292  ...        0        0        1        0
#
# [5 rows x 40 columns]

# %%
# Teste e avaliação de modelos específicos

# %%
model_xg = xgb.XGBClassifier(n_jobs=-1, objective='binary:logistic')

# %%
pipeline = Pipeline([('scaler',  StandardScaler()),
            ('XGBClassifier', xgb.XGBClassifier())])

# %%
model = RandomizedSearchCV(n_iter=10000, estimator = model_xg, param_distributions={}, n_jobs=-1, verbose=10, cv=5, scoring='roc_auc')

# %%
#model.fit(X_train, y_train)
#pipeline.fit(X_train, y_train)
model_xg.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
#y_pred = model.predict_proba(X_test)
#y_pred = pipeline.predict_proba(X_test)
y_pred = model_xg.predict_proba(X_test)
y_pred
# Out:
# array([[0.88536805, 0.11463197],
#        [0.28894424, 0.71105576],
#        [0.2572226 , 0.7427774 ],
#        [0.46382254, 0.53617746],
#        [0.8385416 , 0.1614584 ],
#        [0.8494977 , 0.15050232],
#        [0.5242932 , 0.4757068 ],
#        [0.8898921 , 0.11010792],
#        [0.8555701 , 0.14442994],
#        [0.5711124 , 0.42888764],
#        [0.5212599 , 0.47874013],
#        [0.9192364 , 0.08076356],
#        [0.87765485, 0.12234516],
#        [0.64211106, 0.35788897],
#        [0.7876173 , 0.21238264],
#        [0.90195477, 0.09804522],
#        [0.87537664, 0.12462337],
#        [0.03095698, 0.969043  ],
#        [0.94211775, 0.05788226],
#        [0.9411283 , 0.05887166],
#        [0.81636524, 0.18363473],
#        [0.88665795, 0.11334207],
#        [0.03229654, 0.96770346],
#        [0.9330236 , 0.0669764 ],
#        [0.9033921 , 0.09660795],
#        [0.43562847, 0.5643715 ],
#        [0.04548836, 0.95451164],
#        [0.5876852 , 0.41231474],
# ...

# %%
dados_test['Survived'] = y_pred[:, 1]
dados_test.tail()
# Out:
#      PassengerId  Survived  Age  SibSp  ...  Cabin_F  Cabin_G  Cabin_N  Cabin_T
# 263          197  0.096608   29      0  ...        0        0        1        0
# 264          762  0.033712   41      0  ...        0        0        1        0
# 265           99  0.944271   34      0  ...        0        0        1        0
# 266          185  0.513089    4      0  ...        0        0        1        0
# 267            4  0.936060   35      1  ...        0        0        0        0
#
# [5 rows x 42 columns]

# %%
dados_test.shape
# Out:
# (268, 42)

# %%
#caminho = 'drive/My Drive/Estudos/titanic-train/submissões/submissao_21.csv'
#dados_test[['PassengerId', 'Survived']].to_csv(caminho, index=False)

# %%
# GridSearch na melhor técnica de classificação

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
resultados_3 = pd.read_csv('resultados_treino-3_3.csv', sep=';')
resultados_3.head()
# Out:
#                   tecnica  ...  versao_dados
# 0      AdaBoostClassifier  ...           3.3
# 1       BaggingClassifier  ...           3.3
# 2             BernoulliNB  ...           3.3
# 3  CalibratedClassifierCV  ...           3.3
# 4  DecisionTreeClassifier  ...           3.3
#
# [5 rows x 20 columns]

# %%
resultados_3.loc[(resultados_3['identificador_aleatorio1'] == 940418) & (resultados_3['identificador_aleatorio2'] == 7228513)]
# Out:
#              tecnica  ...  versao_dados
# 1  BaggingClassifier  ...           3.3
#
# [1 rows x 20 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tratado, y_train_tratado, test_size=0.2, random_state=18)

# %%
parametros_bg = {
          'n_estimators': [ 1,  2,  3,  8,  9, 10, 11, 13, 17, 19, 20, 26, 27, 28, 30, 31, 32, 34, 36, 38, 40, 41, 42, 43, 44, 46, 50, 52, 53, 54, 56, 57, 58, 61, 66, 70, 71, 76, 77, 78, 79, 85, 87, 88, 92, 94, 97, 98, 99,100],
          'bootstrap_features': [True, False],
          'bootstrap': [True, False],          
          'oob_score': [True, False],
          'warm_start': [True, False]          
      }

parametros_bg_standard = {
          'standard_scaler__with_mean': [True, False],
          'standard_scaler__with_std': [True, False],
          'BaggingClassifier__n_estimators': [ 1,  2,  3,  8,  9, 10, 11, 13, 17, 19, 20, 26, 27, 28, 30, 31, 32, 34, 36, 38, 40, 41, 42, 43, 44, 46, 50, 52, 53, 54, 56, 57, 58, 61, 66, 70, 71, 76, 77, 78, 79, 85, 87, 88, 92, 94, 97, 98, 99,100],
          'BaggingClassifier__bootstrap_features': [True, False],
          'BaggingClassifier__bootstrap': [True, False],          
          'BaggingClassifier__oob_score': [True, False],
          'BaggingClassifier__warm_start': [True, False]
          
      }

# %%
parametros_rf_standard = {
          'standard_scaler__with_mean': [True, False],
          'standard_scaler__with_std': [True, False],
          'RandomForestClassifier__n_estimators': [10,50,100,200,400],
          'RandomForestClassifier__criterion': ('gini', 'entropy'),
          'RandomForestClassifier__max_features': ('auto', 'sqrt', 'log2', None),
          'RandomForestClassifier__bootstrap': [True, False],
          'RandomForestClassifier__oob_score': [True, False],
          'RandomForestClassifier__warm_start': [True, False],
          'RandomForestClassifier__class_weight': ('balanced', 'balanced_subsample', None)
          
      }

# %%
pipeline_bg = Pipeline([('standard_scaler', StandardScaler()),
          ('BaggingClassifier', BaggingClassifier())])

# %%
pipeline_rf = Pipeline([('standard_scaler', StandardScaler()),
          ('RandomForestClassifier', RandomForestClassifier())])

# %%
model_bg = BaggingClassifier()

# %%
grid = GridSearchCV(pipeline_rf, parametros_rf_standard, scoring='roc_auc', cv=6, n_jobs=-1, verbose=2)

# %%
grid.fit(X_train_tratado, y_train_tratado)
# Out:
# Fitting 6 folds for each of 3840 candidates, totalling 23040 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 940 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 1453 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 2182 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 2857 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 3702 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 4667 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done 5720 tasks      | elapsed: 27.8min
# [Parallel(n_jobs=-1)]: Done 6995 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done 8168 tasks      | elapsed: 41.5min
# [Parallel(n_jobs=-1)]: Done 9619 tasks      | elapsed: 48.0min
# ...

# %%
grid.best_params_
# Out:
# {'RandomForestClassifier__bootstrap': True,
#  'RandomForestClassifier__class_weight': None,
#  'RandomForestClassifier__criterion': 'entropy',
#  'RandomForestClassifier__max_features': None,
#  'RandomForestClassifier__n_estimators': 200,
#  'RandomForestClassifier__oob_score': False,
#  'RandomForestClassifier__warm_start': False,
#  'standard_scaler__with_mean': True,
#  'standard_scaler__with_std': False}

# %%
predict = grid.predict_proba(X_test_tratado)
predict
# Out:
# array([[0.935     , 0.065     ],
#        [0.105     , 0.895     ],
#        [0.17      , 0.83      ],
#        [0.735     , 0.265     ],
#        [0.60900397, 0.39099603],
#        [0.99      , 0.01      ],
#        [0.39      , 0.61      ],
#        [0.905     , 0.095     ],
#        [0.995     , 0.005     ],
#        [0.7575    , 0.2425    ],
#        [0.765     , 0.235     ],
#        [0.985     , 0.015     ],
#        [0.955     , 0.045     ],
#        [0.81833333, 0.18166667],
#        [0.62475397, 0.37524603],
#        [0.90653898, 0.09346102],
#        [0.68      , 0.32      ],
#        [0.035     , 0.965     ],
#        [0.99      , 0.01      ],
#        [0.92      , 0.08      ],
#        [0.53      , 0.47      ],
#        [0.985     , 0.015     ],
#        [0.005     , 0.995     ],
#        [0.995     , 0.005     ],
#        [0.85220934, 0.14779066],
#        [0.10583333, 0.89416667],
#        [0.015     , 0.985     ],
#        [0.40041667, 0.59958333],
# ...

# %%
dados_test['Survived'] = predict[:, 1]
dados_test.head()
# Out:
#    PassengerId  Survived  Age  SibSp  ...  Cabin_F  Cabin_G  Cabin_N  Cabin_T
# 0          132  0.065000   20      0  ...        0        0        1        0
# 1           39  0.895000   18      1  ...        0        0        1        0
# 2          756  0.830000    0      1  ...        0        0        1        0
# 3          660  0.265000   58      0  ...        0        0        0        0
# 4          799  0.390996   30      0  ...        0        0        1        0
#
# [5 rows x 42 columns]
