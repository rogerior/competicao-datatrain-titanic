# %% [markdown]
# Tratamentos para serem realizados:
#
#
# 1.   No atributo 'Name', extrair a segunda palavra do nome. Exemplo: 'Hawksford, Mr. Walter James' -> 'Mr.', posteriormente binarizar este atributo
# 2.   Binarizar atributos: 'Pclass', 'Sex', 'Embarked', 'Name'
# 3.   Atributo 'Age': Remover as casas decimais e atribuir a média nos valores nulos
# 4.   Atributos 'SibSp' e 'Parch': converter para informar se o passageiro tem ou não parentes (0 ou 1). Regra: 'SibSp', 'Parch' = 0 atribua 0; 'SibSp', 'Parch' maior que 0 atribua 1
# 5.   Atributos 'Ticket' e 'Cabin': descartar
# 6.   Verificar correlação dos atributos para uma possível seleção de apenas os atributos mais relevantes

# %%
import pandas as pd

# %%
dados = pd.read_csv('drive/My Drive/Estudos/titanic-train/dados/train.csv')

dados.head()
# Out:
#    PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0          476         0       1  ...   52.0000   A14         S
# 1           57         1       2  ...   10.5000   NaN         S
# 2          259         1       1  ...  512.3292   NaN         C
# 3          741         1       1  ...   30.0000   D45         S
# 4          699         0       1  ...  110.8833   C68         C
#
# [5 rows x 12 columns]

# %%
dados.shape
# Out:
# (623, 12)

# %%
corr = dados.corr()
corr
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.004285 -0.021308  ... -0.021790 -0.013267  0.017401
# Survived       -0.004285  1.000000 -0.340316  ... -0.029924  0.091704  0.252330
# Pclass         -0.021308 -0.340316  1.000000  ...  0.068859  0.022406 -0.557533
# Age             0.042452 -0.054964 -0.366047  ... -0.319541 -0.200870  0.088766
# SibSp          -0.021790 -0.029924  0.068859  ...  1.000000  0.408458  0.156850
# Parch          -0.013267  0.091704  0.022406  ...  0.408458  1.000000  0.207608
# Fare            0.017401  0.252330 -0.557533  ...  0.156850  0.207608  1.000000
#
# [7 rows x 7 columns]

# %%
corr['Survived'].sort_values()
# Out:
# Pclass        -0.340316
# Age           -0.054964
# SibSp         -0.029924
# PassengerId   -0.004285
# Parch          0.091704
# Fare           0.252330
# Survived       1.000000
# Name: Survived, dtype: float64

# %%
dados['SibSp'].value_counts()
# Out:
# 0    418
# 1    150
# 2     23
# 4     14
# 3     10
# 8      4
# 5      4
# Name: SibSp, dtype: int64

# %%
dados['Parch'].value_counts()
# Out:
# 0    471
# 1     80
# 2     60
# 3      5
# 5      3
# 4      3
# 6      1
# Name: Parch, dtype: int64

# %%
dados['Fare'].min()
# Out:
# 0.0

# %%
dados[dados['Name'].str.contains('Jonkheer')]['Name'].values
# Out:
# array(['Reuchlin, Jonkheer. John George'], dtype=object)

# %%
dados['Ticket'].unique()
# Out:
# array(['110465', 'C.A. 31026', 'PC 17755', '16988', '17421', '1601',
#        '350052', '113505', 'STON/O2. 3101290', '312993', 'A/4. 34244',
#        '2666', '370372', '343095', '350404', 'STON/O2. 3101282', '14312',
#        'W./C. 6607', '330923', '17453', '350060', '244367', '382649',
#        'C.A. 33111', '2690', 'SOTON/OQ 392086', '2680', '349245', '28425',
#        '29751', '330877', '29011', 'PC 17593', '113059', '349239',
#        '382652', '315094', '349252', 'A/5. 13032', '113503', 'C.A. 29395',
#        'PC 17761', '347076', 'PC 17610', '111426', '28424', 'WE/P 5735',
#        'A/4 48871', '36963', '12460', 'W./C. 14258', '111361',
#        'STON/O2. 3101283', '110152', '113572', '349909', '371060',
#        'PC 17611', '365226', '347063', '347082', 'W./C. 6608', '2687',
#        '349249', '26360', '349227', '231919', '244278', 'PC 17485',
#        'C.A. 2673', '13507', '323592', 'A/5. 3337', '350047', '350025',
# ...
